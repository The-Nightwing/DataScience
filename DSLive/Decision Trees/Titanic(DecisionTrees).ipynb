# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv('./train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=data.drop(['PassengerId','Name','Ticket','Fare','Cabin','Embarked'],axis=1)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch
# 0         0       3    male  22.0      1      0
# 1         1       1  female  38.0      1      0
# 2         1       3  female  26.0      0      0
# 3         1       1  female  35.0      1      0
# 4         0       3    male  35.0      0      0

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch
# count  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594
# std      0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000

# %%
#in the above descrive there's no column for Sex, becuase decribe() only shows data for numeric coulumns.
#we will use label encoders for this to assign a label to male and female

# %%
label=LabelEncoder()

# %%
label.fit_transform?
# Out:
# Signature: label.fit_transform(y)
# Docstring:
# Fit label encoder and return encoded labels
#
# Parameters
# ----------
# y : array-like of shape [n_samples]
#     Target values.
#
# Returns
# -------
# y : array-like of shape [n_samples]
# File:      c:\users\verma\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py
# Type:      method

# %%
data["Sex"]=label.fit_transform(data['Sex'])

# %%
data.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000

# %%
#now sex is on the describe list, but there is no 891 rows of age becuase some are filled as NA
#so we will assign new ages based upon what ages are assigned to others based on all the features

# %%
complete=data.dropna() #to drop row contaning any no. of NA

# %%
complete.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695    0.634454   29.699118    0.512605    0.431373
# std      0.491460    0.838250    0.481921   14.526497    0.929783    0.853289
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    2.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    1.000000
# max      1.000000    3.000000    1.000000   80.000000    5.000000    6.000000

# %%
table=complete.groupby(['Sex','Pclass']).mean()[['Age']].reset_index() #age is calculated on the basis of Sex and Pclass feature
#now we have all ages according to differnent sex and Pclass, let start filling the tables
#WE CAN also use sklearn.imputer to do that or, complete or data.fillna(data["age"].mean())

# %%
complete.groupby?
# Out:
# Signature:
# complete.groupby(
#     by=None,
#     axis=0,
#     level=None,
#     as_index: bool = True,
#     sort: bool = True,
#     group_keys: bool = True,
#     squeeze: bool = False,
#     observed: bool = False,
# ) -> 'groupby_generic.DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, or list of labels
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
#     aligned; see ``.align()`` method). If an ndarray is passed, the
# ...

# %%
table #age ki predictions according to sex and class
# Out:
#    Sex  Pclass        Age
# 0    0       1  34.611765
# 1    0       2  28.722973
# 2    0       3  21.750000
# 3    1       1  41.281386
# 4    1       2  30.740707
# 5    1       3  26.507589

# %%
def fill_age(row):
    if row.isna()['Age']:
        row['Age']= table.loc[(table.Sex == row["Sex"]) & (table.Pclass == row["Pclass"])].Age.mean() #it will give corresponding age, to for row["sex"](us row m sex ki value)&&,row["pclass"]

    return row 

processed=data.apply(fill_age,axis=1)

# %%
data.apply?
# Out:
# Signature: data.apply(func, axis=0, raw=False, result_type=None, args=(), **kwds)
# Docstring:
# Apply a function along an axis of the DataFrame.
#
# Objects passed to the function are Series objects whose index is
# either the DataFrame's index (``axis=0``) or the DataFrame's columns
# (``axis=1``). By default (``result_type=None``), the final return type
# is inferred from the return type of the applied function. Otherwise,
# it depends on the `result_type` argument.
#
# Parameters
# ----------
# func : function
#     Function to apply to each column or row.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Axis along which the function is applied:
#
#     * 0 or 'index': apply function to each column.
#     * 1 or 'columns': apply function to each row.
#
# raw : bool, default False
#     Determines if row or column is passed as a Series or ndarray object:
#
#     * ``False`` : passes each row or column as a Series to the
#       function.
# ...

# %%
X=processed
X
# Out:
#      Survived  Pclass  Sex    Age  SibSp  Parch
# 0         0.0     3.0  1.0  22.00    1.0    0.0
# 1         1.0     1.0  0.0  38.00    1.0    0.0
# 2         1.0     3.0  0.0  26.00    0.0    0.0
# 3         1.0     1.0  0.0  35.00    1.0    0.0
# 4         0.0     3.0  1.0  35.00    0.0    0.0
# ..        ...     ...  ...    ...    ...    ...
# 886       0.0     2.0  1.0  27.00    0.0    0.0
# 887       1.0     1.0  0.0  19.00    0.0    0.0
# 888       0.0     3.0  0.0  21.75    1.0    2.0
# 889       1.0     1.0  1.0  26.00    0.0    0.0
# 890       0.0     3.0  1.0  32.00    0.0    0.0
#
# [891 rows x 6 columns]

# %%
#now the rows are filled
#it can also be done by fillna method

# %%
#lets define in prateek sir's way

# %%
def entropy(col):
    
    data_=np.unique(col,return_counts=True)
    n=col.shape[0]
    entro=0.0
    for i in data_[1]: #data_[1] has frequencies of data in that column
        p=i/n #probability
        entro+=-1.0*p*np.log2(p)
        
    return entro

# %%
def divide_data(x_data,fkey,fval): #fvalue is the threshhold value for deciding to throw data inn left or right, fkey is column name.
    
    x_right=pd.DataFrame([],columns=x_data.columns)
    x_left=pd.DataFrame([], columns=x_data.columns)
    
    for ix in range(x_data.shape[0]):
        
        val=x_data[fkey].loc[ix] #to take that particluar value of fkey column and ix row , issi value se fval check krenge

        if val<fval:
            x_left=x_left.append(x_data.loc[ix]) #append whole ix row  
        else: 
            x_right=x_right.append(x_data.loc[ix])
        
    return x_left,x_right

# %%
def info_gain(x_data,fkey,fval):
    
    left,right=divide_data(x_data,fkey,fval)
    #now find out percentage of data in both left and right
    l=float(left.shape[0])/x_data.shape[0]
    r=float(right.shape[0])/x_data.shape[0]
    
    #agar ek hi side p sare examples chle gye mtlb min hogya info_gain aur return krdo
    
    if left.shape[0]==0 or right.shape[0]==0:
        return -99999999
    
    i_gain=entropy(x_data)-(l*entropy(left.Survived)+r*entropy(right.Survived))
    
    return i_gain

# %%
class DecisionTree:
    
    def __init__(self,depth=0,max_depth=5):
        self.left=None
        self.right=None
        self.fkey=None #about which feature im splitting
        self.fval=None #threshhold for left right distribution
        self.max_depth=max_depth
        self.depth=depth
        
    def train(self,X_train):
        features=['Pclass','Sex','Age','SibSp','Parch']
        info_gains=[] #to store all info gains of the goven columns
        
        for ix in features:
            i_gain=info_gain(X_train,ix,X_train[ix].mean())
            info_gains.append(i_gain)
            
        self.fkey=features[np.argmax(info_gains)]
        self.fval=X_train[self.fkey].mean()
        
        #split
        x_left,x_right=divide_data(X_train,self.fkey,self.fval)
        x_left=x_left.reset_index(drop=True) #this is because when we divide, if lets say from 1,2,3,4,5 rows--> 2,3,4 goes in left so the numbering should be as 1-2-3 and not as 2,3,4 
        x_right=x_right.reset_index(drop=True)
        
        print('making tree, feature:'+self.fkey)
        
        #when leaf node is encountered
        if x_left.shape[0]==0 or x_right.shape[0]==0: #terminal node
            if X_train.Survived.mean()>=0.5: #zyada +ve cases than negative
                self.target="Survive"
            else:
                self.target="Dead"
            return
                
        #if depth>=max_Depth
        if self.depth >= self.max_depth:   
            if X_train.Survived.mean()>=0.5:
                self.target="Survive"
                
            else:
                self.target="Dead"
            
            return
                
        #recursive case to build the tree
        self.left=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.left.train(x_left)
        
        self.right=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.right.train(x_right)
        
        #checking at every node too
        if X_train.Survived.mean()>=0.5:#zyada +ve cases than negative
            self.target="Survive"
        else:
            self.target="Dead"   
        return
    
    def predict(self,test):
        
        if test[self.fkey] > self.fval: #matlab right m jaao
            if self.right is None: #leaf node or we can say if the node at which we are has no child.
                return self.target
            return self.right.predict(test) #keep exploring right subtree
        else:
            if self.left is None:
                return self.target
            return self.left.predict(test)

# %%
#train-test

# %%
split=int(0.7*X.shape[0])
x_train=X[:split]
x_test=X[split:]
x_test=x_test.reset_index(drop=True)

# %%
d=DecisionTree()

# %%
d.train(X)
# Out:
# making tree, feature:Sex
# making tree, feature:Pclass
# making tree, feature:Pclass
# making tree, feature:Parch
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Parch
# making tree, feature:Age
# making tree, feature:SibSp
# making tree, feature:Parch
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Parch
# making tree, feature:Age
# making tree, feature:SibSp
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:SibSp
# making tree, feature:Age
# making tree, feature:SibSp
# making tree, feature:SibSp
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Age
# making tree, feature:Parch
# making tree, feature:SibSp
# making tree, feature:SibSp
# making tree, feature:Pclass
# making tree, feature:Pclass
# making tree, feature:Age
# ...

# %%
x_test_file=pd.read_csv("C:/Users/verma/Desktop/DS Live/Decision Trees/test.csv")

# %%
data_test=x_test_file.drop(['PassengerId','Name','Ticket','Fare','Cabin','Embarked'],axis=1)
data_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch
# 0         3    male  34.5      0      0
# 1         3  female  47.0      1      0
# 2         2    male  62.0      0      0
# 3         3    male  27.0      0      0
# 4         3  female  22.0      1      1
# ..      ...     ...   ...    ...    ...
# 413       3    male   NaN      0      0
# 414       1  female  39.0      0      0
# 415       3    male  38.5      0      0
# 416       3    male   NaN      0      0
# 417       3    male   NaN      1      1
#
# [418 rows x 5 columns]

# %%
data_test.describe()
# Out:
#            Pclass         Age       SibSp       Parch
# count  418.000000  332.000000  418.000000  418.000000
# mean     2.265550   30.272590    0.447368    0.392344
# std      0.841838   14.181209    0.896760    0.981429
# min      1.000000    0.170000    0.000000    0.000000
# 25%      1.000000   21.000000    0.000000    0.000000
# 50%      3.000000   27.000000    0.000000    0.000000
# 75%      3.000000   39.000000    1.000000    0.000000
# max      3.000000   76.000000    8.000000    9.000000

# %%
data_test=data_test.fillna(data_test["Age"].mean())
data_test["Sex"]=label.fit_transform(data_test['Sex'])

# %%
data_test.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch
# count  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     2.265550    0.636364   30.272590    0.447368    0.392344
# std      0.841838    0.481622   12.634534    0.896760    0.981429
# min      1.000000    0.000000    0.170000    0.000000    0.000000
# 25%      1.000000    0.000000   23.000000    0.000000    0.000000
# 50%      3.000000    1.000000   30.272590    0.000000    0.000000
# 75%      3.000000    1.000000   35.750000    1.000000    0.000000
# max      3.000000    1.000000   76.000000    8.000000    9.000000

# %%
y_pred=[]

for ix in range(x_test.shape[0]):
    y_pred.append(d.predict(x_test.loc[ix]))

# %%
y_actual=x_test['Survived']

# %%
y_pred=label.fit_transform(y_pred)

# %%
y_pred.shape
# Out:
# (268,)

# %%
y_actual.shape
# Out:
# (268,)

# %%
acc=np.sum(np.array(y_pred)==np.array(y_actual))/y_pred.shape[0]

# %%
acc
# Out:
# 0.8470149253731343
