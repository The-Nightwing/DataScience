# %%
b=100
c=b
c=c-6
print(b)
print(c)
# Out:
# 100
# 94

# %%
e=666
f=666
e is f
# Out:
# False

# %%
Line="Hello World"
print(Line.replace('Hello','he'))
# Out:
# he World

# %%
import requests

# %%
from PIL import Image

# %%
img=Image.open("naruto.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x13ABEF72A08>

# %%
type(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a85b415ea517> in <module>
# ----> 1 type(img)
#
# NameError: name 'img' is not defined
